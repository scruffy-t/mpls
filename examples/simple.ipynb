# %%
import matplotlib.pyplot as plt
import numpy as np
import mpls

# %matplotlib inline


def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
mpls.use(context='water_resour_res', style='water_resour_res', palette='rwth-ci')
sinplot()
# Out:
# DEBUG:mpls.mpls:trying urlopen for file https://raw.githubusercontent.com/scruffy-t/mpls/master/stylelib/context/water_resour_res.json
# DEBUG:mpls.mpls:loaded raw context file from URL
# DEBUG:mpls.cache:added context file "water_resour_res" to cache
# DEBUG:mpls.mpls:converting file content to Python dict
# DEBUG:mpls.mpls:trying urlopen for file https://raw.githubusercontent.com/scruffy-t/mpls/master/stylelib/style/water_resour_res.json
# DEBUG:mpls.mpls:loaded raw style file from URL
# DEBUG:mpls.cache:added style file "water_resour_res" to cache
# DEBUG:mpls.mpls:converting file content to Python dict
# DEBUG:mpls.mpls:trying urlopen for file https://raw.githubusercontent.com/scruffy-t/mpls/master/stylelib/palette/rwth-ci.json
# DEBUG:mpls.mpls:loaded raw palette file from URL
# DEBUG:mpls.cache:added palette file "rwth-ci" to cache
# DEBUG:mpls.mpls:converting file content to Python dict

# %%
with mpls.temp(context='a5'):
    sinplot()
# Out:
# DEBUG:mpls.mpls:trying urlopen for file https://raw.githubusercontent.com/scruffy-t/mpls/master/stylelib/context/a5.json
# DEBUG:mpls.mpls:loaded raw context file from URL
# DEBUG:mpls.cache:added context file "a5" to cache
# DEBUG:mpls.mpls:converting file content to Python dict

# %%
# mixed use of matplotlib styles and mpls styles
mpls.use('default', 'dark_background', context='a5')
sinplot()
# Out:
# DEBUG:mpls.mpls:loaded raw context file from cache
# DEBUG:mpls.mpls:converting file content to Python dict

# %%
with mpls.temp(context='a5-landscape', reset=True):
    sinplot()
# Out:
# DEBUG:mpls.mpls:trying urlopen for file https://raw.githubusercontent.com/scruffy-t/mpls/master/stylelib/context/a5-landscape.json
# DEBUG:mpls.mpls:loaded raw context file from URL
# DEBUG:mpls.cache:added context file "a5-landscape" to cache
# DEBUG:mpls.mpls:converting file content to Python dict
